# %% [markdown]
# # Testing Listmonk transactional

# %%
# %load_ext jupyter_black
# %load_ext autoreload
# %autoreload 2

# %%
from src.email import listmonk

# %%
to_emails = [("Tristan Downing", "<tristan.downing@un.org>")]
cc_emails = [("Zachary Arno", "<zachary.arno@un.org")]

# %%
listmonk.send_transactional(
    to_emails=to_emails, 
    cc_emails=cc_emails, 
    subject="Listmonk transactional test",
    data={"content": "Test content, populated from Python"}
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 listmonk.send_transactional(
#       2     to_emails=to_emails,
#       3     cc_emails=cc_emails,
#       4     subject="Listmonk transactional test",
#       5     data={"content": "Test content, populated from Python"}
#       6 )
#
# File ~/OCHA/repos/ds-fms-tc-outlook/src/email/listmonk.py:87, in send_transactional(to_emails, subject, template_id, cc_emails, data)
#      63 payload = {
#      64     "subscriber_email": to_emails[0][1],  # primary recipient
#      65     "template_id": template_id,
#    (...)
#      81     ],
#      82 }
#      84 r = requests.post(
#      85     f"{BASE_URL}/tx", auth=(USERNAME, PASSWORD), json=payload
#      86 )
# ---> 87 r.raise_for_status()
#      88 return r.json()
#
# File ~/.pyenv/versions/ds-fms-tc-outlook/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://listmonk-demo-afhcg8e2hde0fxca.eastus2-01.azurewebsites.net/api/tx
